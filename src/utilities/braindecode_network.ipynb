# %% [markdown]
# ## Import libaries

# %%
import braindecode
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import braindecode
#
# File c:\Users\Bruger\Documents\hybrid_bci\.venv\Lib\site-packages\braindecode\__init__.py:1
# ----> 1 from .classifier import EEGClassifier
#       2 from .regressor import EEGRegressor
#       3 from .version import __version__
#
# File c:\Users\Bruger\Documents\hybrid_bci\.venv\Lib\site-packages\braindecode\classifier.py:11
#       1 # Authors: Maciej Sliwowski <maciek.sliwowski@gmail.com>
#       2 #          Robin Schirrmeister <robintibor@gmail.com>
#       3 #          Lukas Gemein <l.gemein@gmail.com>
#    (...)
#       6 #
#       7 # License: BSD (3-clause)
#       9 import warnings
# ---> 11 from skorch import NeuralNet
#      12 from skorch.callbacks import EpochScoring
#      13 from skorch.classifier import NeuralNetClassifier
#
# ...
